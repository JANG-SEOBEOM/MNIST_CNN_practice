# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
import numpy as np

# %%
# Loading Model
classifier = load_model('/content/drive/MyDrive/MNIST/Colab Notebooks/cnn_numbers.keras')

# Importing Test Images
test_image = image.load_img('/content/drive/MyDrive/Colab Notebooks/MNIST Dataset JPG format/MNIST - JPG - testing/4/1057.jpg',
                            target_size = (28,28),
                            color_mode = 'grayscale')
# Transform to  Numpy array
test_image = image.img_to_array(test_image)

# Normalization
test_image = test_image / 255.0

# Expand dimension
test_image = np.expand_dims(test_image, axis = 0)

# Prediction
result = classifier.predict(test_image)

index = (np.where(result == result.max()))
prob = np.max(result)
print(index)
print(prob)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1923/3280871539.py in <cell line: 0>()
#       1 # Loading Model
# ----> 2 classifier = load_model('/content/drive/MyDrive/MNIST/Colab Notebooks/cnn_numbers.keras')
#       3
#       4 # Importing Test Images
#       5 test_image = image.load_img('/content/drive/MyDrive/Colab Notebooks/MNIST Dataset JPG format/MNIST - JPG - testing/4/1057.jpg',
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     201         )
#     202     elif str(filepath).endswith(".keras"):
# --> 203         raise ValueError(
#     204             f"File not found: filepath={filepath}. "
#     205             "Please ensure the file is an accessible `.keras` "
#
# ...
